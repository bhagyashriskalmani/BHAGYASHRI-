# %%
area="4.5"
fields=7
Total_area=float(area)*fields
print("Total cultivated area:",Total_area,"acres")
# Out:
# Total cultivated area: 31.5 acres

# %%
area="2.5"
fields=9
Total_area=float(area)*fields
print("Total cultivated area:",Total_area,"acres")
# Out:
# Total cultivated area: 22.5 acres

# %%
number_of_fields=5
area_per_field=2.5
crop_name="Maize"
irrigation_available=True
print("crop_name:",crop_name)
print("number_of_fields:",number_of_fields)
print("area_per_field:",area_per_field)
print("irrigation_avilable",irrigation_available)
# Out:
# crop_name: Maize
# number_of_fields: 5
# area_per_field: 2.5
# irrigation_avilable True

# %%
number_of_fields=10
area_per_field=2.5
crop_name="WHEAT"
irrigation_available=False
print("crop_name:",crop_name)
print("number_of_fields:",number_of_fields)
print("area_per_field:",area_per_field)
print("irrigation_avilable",irrigation_available)
# Out:
# crop_name: Maize
# number_of_fields: 5
# area_per_field: 2.5
# irrigation_avilable True
